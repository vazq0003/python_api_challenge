# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 597

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f'{url}appid={weather_api_key}&q={city}&units=metric'
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | adamstown
# Processing Record 2 of Set 1 | avarua
# Processing Record 3 of Set 1 | campina grande
# Processing Record 4 of Set 1 | bandipura
# Processing Record 5 of Set 1 | tanrake village
# City not found. Skipping...
# Processing Record 6 of Set 1 | thompson
# Processing Record 7 of Set 1 | bintulu
# Processing Record 8 of Set 1 | isafjordur
# Processing Record 9 of Set 1 | awjilah
# Processing Record 10 of Set 1 | houghton
# Processing Record 11 of Set 1 | akobo
# Processing Record 12 of Set 1 | padang
# Processing Record 13 of Set 1 | lubumbashi
# Processing Record 14 of Set 1 | urengoy
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | severo-yeniseyskiy
# Processing Record 17 of Set 1 | hanceville
# Processing Record 18 of Set 1 | mukalla
# Processing Record 19 of Set 1 | kualakapuas
# Processing Record 20 of Set 1 | kapuskasing
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | doetinchem
# Processing Record 23 of Set 1 | iqaluit
# Processing Record 24 of Set 1 | lata
# Processing Record 25 of Set 1 | baoqing
# Processing Record 26 of Set 1 | ha giang
# Processing Record 27 of Set 1 | port-aux-francais
# Processing Record 28 of Set 1 | sisimiut
# Processing Record 29 of Set 1 | qaqortoq
# Processing Record 30 of Set 1 | jiangyou
# Processing Record 31 of Set 1 | grytviken
# Processing Record 32 of Set 1 | nuku'alofa
# Processing Record 33 of Set 1 | bilibino
# Processing Record 34 of Set 1 | khandyga
# Processing Record 35 of Set 1 | conceicao da barra
# Processing Record 36 of Set 1 | selma
# Processing Record 37 of Set 1 | berehove
# Processing Record 38 of Set 1 | iskateley
# Processing Record 39 of Set 1 | sola
# Processing Record 40 of Set 1 | petawawa
# Processing Record 41 of Set 1 | wailua homesteads
# Processing Record 42 of Set 1 | puerto ayora
# Processing Record 43 of Set 1 | ondjiva
# Processing Record 44 of Set 1 | esmeralda
# Processing Record 45 of Set 1 | edinburgh of the seven seas
# Processing Record 46 of Set 1 | puerto natales
# Processing Record 47 of Set 1 | margaret river
# Processing Record 48 of Set 1 | shingu
# Processing Record 49 of Set 1 | talnakh
# Processing Record 50 of Set 1 | mwene-ditu
# Processing Record 0 of Set 2 | ketchikan
# Processing Record 1 of Set 2 | bethel
# Processing Record 2 of Set 2 | lihue
# Processing Record 3 of Set 2 | orsova
# Processing Record 4 of Set 2 | waitangi
# Processing Record 5 of Set 2 | blackmans bay
# Processing Record 6 of Set 2 | albany
# Processing Record 7 of Set 2 | xuddur
# Processing Record 8 of Set 2 | constantia
# Processing Record 9 of Set 2 | queenstown
# Processing Record 10 of Set 2 | port glaud
# City not found. Skipping...
# Processing Record 11 of Set 2 | tual
# Processing Record 12 of Set 2 | kodinsk
# Processing Record 13 of Set 2 | usak
# Processing Record 14 of Set 2 | college
# Processing Record 15 of Set 2 | fort bragg
# Processing Record 16 of Set 2 | mahina
# Processing Record 17 of Set 2 | tsiombe
# Processing Record 18 of Set 2 | belebey
# Processing Record 19 of Set 2 | puerto deseado
# Processing Record 20 of Set 2 | ilulissat
# Processing Record 21 of Set 2 | areia branca
# Processing Record 22 of Set 2 | collie
# Processing Record 23 of Set 2 | neryungri
# Processing Record 24 of Set 2 | tamanrasset
# Processing Record 25 of Set 2 | xinyuan
# Processing Record 26 of Set 2 | kununurra
# Processing Record 27 of Set 2 | sagua la grande
# Processing Record 28 of Set 2 | yirol
# City not found. Skipping...
# Processing Record 29 of Set 2 | tiksi
# Processing Record 30 of Set 2 | itaituba
# Processing Record 31 of Set 2 | boguchany
# Processing Record 32 of Set 2 | ushuaia
# Processing Record 33 of Set 2 | st. john's
# Processing Record 34 of Set 2 | valley city
# Processing Record 35 of Set 2 | sinabang
# Processing Record 36 of Set 2 | opuwo
# Processing Record 37 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 38 of Set 2 | sitka
# Processing Record 39 of Set 2 | lazaro cardenas
# Processing Record 40 of Set 2 | polyarnyy
# Processing Record 41 of Set 2 | vorkuta
# Processing Record 42 of Set 2 | port mathurin
# Processing Record 43 of Set 2 | zangguy
# City not found. Skipping...
# Processing Record 44 of Set 2 | dombarovskiy
# Processing Record 45 of Set 2 | kone
# Processing Record 46 of Set 2 | taltal
# Processing Record 47 of Set 2 | soto la marina
# Processing Record 48 of Set 2 | nova sintra
# Processing Record 49 of Set 2 | faya-largeau
# Processing Record 0 of Set 3 | kingston
# Processing Record 1 of Set 3 | new norfolk
# Processing Record 2 of Set 3 | camabatela
# Processing Record 3 of Set 3 | longyearbyen
# Processing Record 4 of Set 3 | tazovsky
# Processing Record 5 of Set 3 | bowen
# Processing Record 6 of Set 3 | bredasdorp
# Processing Record 7 of Set 3 | georgetown
# Processing Record 8 of Set 3 | fonadhoo
# City not found. Skipping...
# Processing Record 9 of Set 3 | kuqa
# Processing Record 10 of Set 3 | new baltimore
# Processing Record 11 of Set 3 | ferkessedougou
# Processing Record 12 of Set 3 | burang
# Processing Record 13 of Set 3 | pangody
# Processing Record 14 of Set 3 | trat
# Processing Record 15 of Set 3 | west island
# Processing Record 16 of Set 3 | port elizabeth
# Processing Record 17 of Set 3 | udachny
# Processing Record 18 of Set 3 | forked river
# Processing Record 19 of Set 3 | kas
# Processing Record 20 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 21 of Set 3 | peniche
# Processing Record 22 of Set 3 | taro
# Processing Record 23 of Set 3 | atafu village
# Processing Record 24 of Set 3 | lockwood
# Processing Record 25 of Set 3 | strelka
# Processing Record 26 of Set 3 | hawaiian paradise park
# Processing Record 27 of Set 3 | okha
# Processing Record 28 of Set 3 | hilo
# Processing Record 29 of Set 3 | bredy
# Processing Record 30 of Set 3 | ribeira brava
# Processing Record 31 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 32 of Set 3 | campeni
# Processing Record 33 of Set 3 | khilok
# Processing Record 34 of Set 3 | hurricane
# Processing Record 35 of Set 3 | keren
# Processing Record 36 of Set 3 | arkhangel'sk
# Processing Record 37 of Set 3 | mandera
# Processing Record 38 of Set 3 | cat ba
# City not found. Skipping...
# Processing Record 39 of Set 3 | moose jaw
# Processing Record 40 of Set 3 | chonchi
# Processing Record 41 of Set 3 | alofi
# Processing Record 42 of Set 3 | magistral'nyy
# Processing Record 43 of Set 3 | egersund
# Processing Record 44 of Set 3 | jamestown
# Processing Record 45 of Set 3 | acigol
# City not found. Skipping...
# Processing Record 46 of Set 3 | invercargill
# Processing Record 47 of Set 3 | pontianak
# Processing Record 48 of Set 3 | tuineje
# Processing Record 49 of Set 3 | klyuchi
# Processing Record 0 of Set 4 | glennville
# Processing Record 1 of Set 4 | vila franca do campo
# Processing Record 2 of Set 4 | samarra'
# City not found. Skipping...
# Processing Record 3 of Set 4 | inhambane
# Processing Record 4 of Set 4 | dudinka
# Processing Record 5 of Set 4 | papatowai
# Processing Record 6 of Set 4 | machico
# Processing Record 7 of Set 4 | ribeira grande
# Processing Record 8 of Set 4 | port lincoln
# Processing Record 9 of Set 4 | belmonte
# Processing Record 10 of Set 4 | hithadhoo
# Processing Record 11 of Set 4 | kirakira
# Processing Record 12 of Set 4 | olonkinbyen
# Processing Record 13 of Set 4 | sandnessjoen
# Processing Record 14 of Set 4 | fannuj
# City not found. Skipping...
# Processing Record 15 of Set 4 | bonab
# Processing Record 16 of Set 4 | nantucket
# Processing Record 17 of Set 4 | galle
# Processing Record 18 of Set 4 | port alfred
# Processing Record 19 of Set 4 | tura
# Processing Record 20 of Set 4 | keflavik
# Processing Record 21 of Set 4 | bocas del toro
# Processing Record 22 of Set 4 | boden
# Processing Record 23 of Set 4 | lincoln
# Processing Record 24 of Set 4 | badger
# Processing Record 25 of Set 4 | ghadamis
# Processing Record 26 of Set 4 | barretos
# Processing Record 27 of Set 4 | kaa-khem
# Processing Record 28 of Set 4 | hermanus
# Processing Record 29 of Set 4 | rio grande
# Processing Record 30 of Set 4 | hamilton
# Processing Record 31 of Set 4 | xai-xai
# Processing Record 32 of Set 4 | wukari
# Processing Record 33 of Set 4 | lake carmel
# Processing Record 34 of Set 4 | alice springs
# Processing Record 35 of Set 4 | argo
# Processing Record 36 of Set 4 | mermoz boabab
# Processing Record 37 of Set 4 | flying fish cove
# Processing Record 38 of Set 4 | srandakan
# Processing Record 39 of Set 4 | ekenas
# Processing Record 40 of Set 4 | kuala tungkal
# Processing Record 41 of Set 4 | ta`u
# Processing Record 42 of Set 4 | carnarvon
# Processing Record 43 of Set 4 | kavaratti
# Processing Record 44 of Set 4 | arraial do cabo
# Processing Record 45 of Set 4 | lerwick
# Processing Record 46 of Set 4 | barcelos
# Processing Record 47 of Set 4 | kodiak
# Processing Record 48 of Set 4 | san luis de la loma
# Processing Record 49 of Set 4 | san juan bautista
# Processing Record 0 of Set 5 | shalkar
# Processing Record 1 of Set 5 | stanley
# Processing Record 2 of Set 5 | xining
# Processing Record 3 of Set 5 | nuuk
# Processing Record 4 of Set 5 | lompoc
# Processing Record 5 of Set 5 | new plymouth
# Processing Record 6 of Set 5 | inari
# Processing Record 7 of Set 5 | enewetak
# Processing Record 8 of Set 5 | cidreira
# Processing Record 9 of Set 5 | salalah
# Processing Record 10 of Set 5 | uturoa
# Processing Record 11 of Set 5 | zhanjiang
# Processing Record 12 of Set 5 | quellon
# Processing Record 13 of Set 5 | ulsteinvik
# Processing Record 14 of Set 5 | gadzhiyevo
# Processing Record 15 of Set 5 | kharkhorin
# Processing Record 16 of Set 5 | charters towers
# Processing Record 17 of Set 5 | cannonvale
# Processing Record 18 of Set 5 | salinopolis
# Processing Record 19 of Set 5 | general levalle
# Processing Record 20 of Set 5 | n'zeto
# Processing Record 21 of Set 5 | nouadhibou
# Processing Record 22 of Set 5 | san antonio de pale
# Processing Record 23 of Set 5 | tokar
# Processing Record 24 of Set 5 | fale old settlement
# Processing Record 25 of Set 5 | pacific grove
# Processing Record 26 of Set 5 | chayan
# Processing Record 27 of Set 5 | koprivnica
# Processing Record 28 of Set 5 | mirador
# Processing Record 29 of Set 5 | lebyazh'ye
# Processing Record 30 of Set 5 | basco
# Processing Record 31 of Set 5 | menongue
# Processing Record 32 of Set 5 | coos bay
# Processing Record 33 of Set 5 | baruun-urt
# Processing Record 34 of Set 5 | dunhua
# Processing Record 35 of Set 5 | kismayo
# Processing Record 36 of Set 5 | ohara
# Processing Record 37 of Set 5 | crane
# Processing Record 38 of Set 5 | namibe
# Processing Record 39 of Set 5 | iquique
# Processing Record 40 of Set 5 | pathein
# Processing Record 41 of Set 5 | anadyr
# Processing Record 42 of Set 5 | vadso
# Processing Record 43 of Set 5 | jumla
# Processing Record 44 of Set 5 | hadibu
# Processing Record 45 of Set 5 | al jawf
# Processing Record 46 of Set 5 | quiindy
# Processing Record 47 of Set 5 | aasiaat
# Processing Record 48 of Set 5 | wajir
# Processing Record 49 of Set 5 | tramandai
# Processing Record 0 of Set 6 | cockburn town
# Processing Record 1 of Set 6 | arica
# Processing Record 2 of Set 6 | puerto santa
# Processing Record 3 of Set 6 | ust-nera
# Processing Record 4 of Set 6 | tranovaho
# City not found. Skipping...
# Processing Record 5 of Set 6 | whitehorse
# Processing Record 6 of Set 6 | puiesti
# Processing Record 7 of Set 6 | howard springs
# Processing Record 8 of Set 6 | urzhar
# Processing Record 9 of Set 6 | el bauga
# Processing Record 10 of Set 6 | manaure
# Processing Record 11 of Set 6 | homer
# Processing Record 12 of Set 6 | saratamata
# City not found. Skipping...
# Processing Record 13 of Set 6 | teknaf
# Processing Record 14 of Set 6 | utrik
# Processing Record 15 of Set 6 | coquimbo
# Processing Record 16 of Set 6 | bouna
# Processing Record 17 of Set 6 | yuzhno-kurilsk
# Processing Record 18 of Set 6 | pacora
# Processing Record 19 of Set 6 | harar
# Processing Record 20 of Set 6 | codrington
# Processing Record 21 of Set 6 | bandar-e anzali
# Processing Record 22 of Set 6 | saipan
# Processing Record 23 of Set 6 | aimores
# Processing Record 24 of Set 6 | tolanaro
# Processing Record 25 of Set 6 | darwin
# Processing Record 26 of Set 6 | zaysan
# Processing Record 27 of Set 6 | hoemul-li
# Processing Record 28 of Set 6 | paraiso
# Processing Record 29 of Set 6 | isle of lewis
# City not found. Skipping...
# Processing Record 30 of Set 6 | mata-utu
# Processing Record 31 of Set 6 | mili
# Processing Record 32 of Set 6 | labrador city
# Processing Record 33 of Set 6 | chadron
# Processing Record 34 of Set 6 | dryden
# Processing Record 35 of Set 6 | griffith
# Processing Record 36 of Set 6 | douglas
# Processing Record 37 of Set 6 | 'ohonua
# City not found. Skipping...
# Processing Record 38 of Set 6 | boyolali
# Processing Record 39 of Set 6 | portland
# Processing Record 40 of Set 6 | iwanai
# Processing Record 41 of Set 6 | taroa
# Processing Record 42 of Set 6 | sur
# Processing Record 43 of Set 6 | crucecita
# Processing Record 44 of Set 6 | gagliano del capo
# Processing Record 45 of Set 6 | dzhetygara
# Processing Record 46 of Set 6 | bikenibeu village
# Processing Record 47 of Set 6 | san patricio
# Processing Record 48 of Set 6 | newman
# Processing Record 49 of Set 6 | santa terezinha
# Processing Record 0 of Set 7 | novyy urengoy
# Processing Record 1 of Set 7 | augusto correa
# Processing Record 2 of Set 7 | port saint john's
# Processing Record 3 of Set 7 | aykhal
# Processing Record 4 of Set 7 | north bend
# Processing Record 5 of Set 7 | nemuro
# Processing Record 6 of Set 7 | nyanza
# Processing Record 7 of Set 7 | kayangel
# Processing Record 8 of Set 7 | antofagasta
# Processing Record 9 of Set 7 | camalu
# Processing Record 10 of Set 7 | san jose village
# City not found. Skipping...
# Processing Record 11 of Set 7 | bantayan
# Processing Record 12 of Set 7 | mana
# Processing Record 13 of Set 7 | medenine
# Processing Record 14 of Set 7 | laibin
# Processing Record 15 of Set 7 | isla mujeres
# Processing Record 16 of Set 7 | geraldton
# Processing Record 17 of Set 7 | siwa oasis
# Processing Record 18 of Set 7 | gamba
# Processing Record 19 of Set 7 | mount isa
# Processing Record 20 of Set 7 | santo antonio do ica
# Processing Record 21 of Set 7 | muzayri'
# City not found. Skipping...
# Processing Record 22 of Set 7 | muisne
# Processing Record 23 of Set 7 | capo d'orlando
# Processing Record 24 of Set 7 | lochbuie
# Processing Record 25 of Set 7 | zouerate
# Processing Record 26 of Set 7 | cova figueira
# Processing Record 27 of Set 7 | san antonio
# Processing Record 28 of Set 7 | rensselaer
# Processing Record 29 of Set 7 | george town
# Processing Record 30 of Set 7 | tukrah
# Processing Record 31 of Set 7 | zaozersk
# Processing Record 32 of Set 7 | cambria
# Processing Record 33 of Set 7 | altai
# Processing Record 34 of Set 7 | peshawar
# Processing Record 35 of Set 7 | mohr
# Processing Record 36 of Set 7 | medina
# Processing Record 37 of Set 7 | jining
# Processing Record 38 of Set 7 | fuvahmulah
# City not found. Skipping...
# Processing Record 39 of Set 7 | acarau
# Processing Record 40 of Set 7 | harper
# Processing Record 41 of Set 7 | kulp
# Processing Record 42 of Set 7 | luderitz
# Processing Record 43 of Set 7 | laojunmiao
# Processing Record 44 of Set 7 | aizkraukle
# Processing Record 45 of Set 7 | skurup
# Processing Record 46 of Set 7 | lebu
# Processing Record 47 of Set 7 | masterton
# Processing Record 48 of Set 7 | el charco
# Processing Record 49 of Set 7 | gazojak
# Processing Record 0 of Set 8 | port moresby
# Processing Record 1 of Set 8 | likasi
# Processing Record 2 of Set 8 | port-de-paix
# City not found. Skipping...
# Processing Record 3 of Set 8 | crikvenica
# Processing Record 4 of Set 8 | souillac
# Processing Record 5 of Set 8 | suva
# Processing Record 6 of Set 8 | northam
# Processing Record 7 of Set 8 | bodaybo
# Processing Record 8 of Set 8 | camiri
# Processing Record 9 of Set 8 | nar'yan-mar
# Processing Record 10 of Set 8 | kyren
# Processing Record 11 of Set 8 | sanctuary point
# Processing Record 12 of Set 8 | remire-montjoly
# Processing Record 13 of Set 8 | mugia
# Processing Record 14 of Set 8 | east moriches
# Processing Record 15 of Set 8 | horta
# Processing Record 16 of Set 8 | pisco
# Processing Record 17 of Set 8 | mccomb
# Processing Record 18 of Set 8 | storvreta
# Processing Record 19 of Set 8 | papao
# Processing Record 20 of Set 8 | swakopmund
# Processing Record 21 of Set 8 | mananjary
# Processing Record 22 of Set 8 | natal
# Processing Record 23 of Set 8 | ostrov
# Processing Record 24 of Set 8 | mandal
# Processing Record 25 of Set 8 | aioun
# Processing Record 26 of Set 8 | cabedelo
# Processing Record 27 of Set 8 | orumiyeh
# Processing Record 28 of Set 8 | lorengau
# Processing Record 29 of Set 8 | semnan
# Processing Record 30 of Set 8 | afaahiti
# Processing Record 31 of Set 8 | kavieng
# Processing Record 32 of Set 8 | zhuanghe
# Processing Record 33 of Set 8 | nova xavantina
# Processing Record 34 of Set 8 | ballina
# Processing Record 35 of Set 8 | vohipaho
# City not found. Skipping...
# Processing Record 36 of Set 8 | richards bay
# Processing Record 37 of Set 8 | andovoranto
# Processing Record 38 of Set 8 | susuman
# Processing Record 39 of Set 8 | pont-l'abbe
# City not found. Skipping...
# Processing Record 40 of Set 8 | holualoa
# Processing Record 41 of Set 8 | taoudenni
# Processing Record 42 of Set 8 | al hawatah
# Processing Record 43 of Set 8 | bemidji
# Processing Record 44 of Set 8 | yeppoon
# Processing Record 45 of Set 8 | tell city
# Processing Record 46 of Set 8 | rundu
# Processing Record 47 of Set 8 | mount pearl
# Processing Record 48 of Set 8 | selfoss
# Processing Record 49 of Set 8 | balqash
# Processing Record 0 of Set 9 | tezu
# Processing Record 1 of Set 9 | mendefera
# Processing Record 2 of Set 9 | harpswell center
# Processing Record 3 of Set 9 | dunedin
# Processing Record 4 of Set 9 | candido de abreu
# Processing Record 5 of Set 9 | zaragoza
# Processing Record 6 of Set 9 | zeribet el oued
# Processing Record 7 of Set 9 | kapa'a
# Processing Record 8 of Set 9 | ancud
# Processing Record 9 of Set 9 | balabac
# Processing Record 10 of Set 9 | jayapura
# Processing Record 11 of Set 9 | porto de moz
# Processing Record 12 of Set 9 | woodlake
# Processing Record 13 of Set 9 | miyako
# Processing Record 14 of Set 9 | zmeinogorsk
# Processing Record 15 of Set 9 | tikamgarh
# Processing Record 16 of Set 9 | fort st. john
# Processing Record 17 of Set 9 | igarka
# Processing Record 18 of Set 9 | piti village
# Processing Record 19 of Set 9 | egyek
# Processing Record 20 of Set 9 | chambarak
# Processing Record 21 of Set 9 | praia da vitoria
# Processing Record 22 of Set 9 | reggane
# Processing Record 23 of Set 9 | luanda
# Processing Record 24 of Set 9 | buala
# Processing Record 25 of Set 9 | kerikeri
# Processing Record 26 of Set 9 | corozal
# Processing Record 27 of Set 9 | fortaleza
# Processing Record 28 of Set 9 | lanivtsi
# Processing Record 29 of Set 9 | gulf shores
# Processing Record 30 of Set 9 | carutapera
# Processing Record 31 of Set 9 | kijang
# Processing Record 32 of Set 9 | bayville
# Processing Record 33 of Set 9 | ocean shores
# Processing Record 34 of Set 9 | tomatlan
# Processing Record 35 of Set 9 | juneau
# Processing Record 36 of Set 9 | tsiroanomandidy
# Processing Record 37 of Set 9 | naze
# Processing Record 38 of Set 9 | globe
# City not found. Skipping...
# Processing Record 39 of Set 9 | sonsorol village
# City not found. Skipping...
# Processing Record 40 of Set 9 | choma
# Processing Record 41 of Set 9 | gueoul
# City not found. Skipping...
# Processing Record 42 of Set 9 | labuan
# Processing Record 43 of Set 9 | isangel
# Processing Record 44 of Set 9 | weno
# Processing Record 45 of Set 9 | ginir
# Processing Record 46 of Set 9 | noosa heads
# Processing Record 47 of Set 9 | makhambet
# Processing Record 48 of Set 9 | haiku-pauwela
# Processing Record 49 of Set 9 | harstad
# Processing Record 0 of Set 10 | glenfield park
# Processing Record 1 of Set 10 | adur
# Processing Record 2 of Set 10 | mchinji
# Processing Record 3 of Set 10 | forster
# Processing Record 4 of Set 10 | cargados carajos
# City not found. Skipping...
# Processing Record 5 of Set 10 | extrema
# Processing Record 6 of Set 10 | antalaha
# Processing Record 7 of Set 10 | gisborne
# Processing Record 8 of Set 10 | hammerfest
# Processing Record 9 of Set 10 | morehead city
# Processing Record 10 of Set 10 | pul-e khumri
# Processing Record 11 of Set 10 | fada
# Processing Record 12 of Set 10 | rawson
# Processing Record 13 of Set 10 | pemba
# Processing Record 14 of Set 10 | itamaraju
# Processing Record 15 of Set 10 | shuangcheng
# Processing Record 16 of Set 10 | ola
# Processing Record 17 of Set 10 | yarmouth
# Processing Record 18 of Set 10 | araioses
# Processing Record 19 of Set 10 | banfora
# Processing Record 20 of Set 10 | yaren
# Processing Record 21 of Set 10 | devinuwara
# City not found. Skipping...
# Processing Record 22 of Set 10 | smirnykh
# Processing Record 23 of Set 10 | muynoq
# Processing Record 24 of Set 10 | twon-brass
# Processing Record 25 of Set 10 | namtsy
# Processing Record 26 of Set 10 | kingscliff
# Processing Record 27 of Set 10 | kem'
# Processing Record 28 of Set 10 | rutland
# Processing Record 29 of Set 10 | sukhobezvodnoye
# Processing Record 30 of Set 10 | micheweni
# Processing Record 31 of Set 10 | prado
# Processing Record 32 of Set 10 | dingras
# Processing Record 33 of Set 10 | sonoita
# Processing Record 34 of Set 10 | mulayjah
# Processing Record 35 of Set 10 | bandarbeyla
# Processing Record 36 of Set 10 | patnanungan
# Processing Record 37 of Set 10 | pagar alam
# Processing Record 38 of Set 10 | tabas
# Processing Record 39 of Set 10 | quelimane
# Processing Record 40 of Set 10 | vilyuchinsk
# Processing Record 41 of Set 10 | nizhnesortymskiy
# Processing Record 42 of Set 10 | isheyevka
# Processing Record 43 of Set 10 | necochea
# Processing Record 44 of Set 10 | buka
# Processing Record 45 of Set 10 | san juan de miraflores
# Processing Record 46 of Set 10 | wynyard
# Processing Record 47 of Set 10 | el colorado
# Processing Record 48 of Set 10 | daru
# Processing Record 49 of Set 10 | oistins
# Processing Record 0 of Set 11 | olinda
# Processing Record 1 of Set 11 | rio verde
# Processing Record 2 of Set 11 | pandan
# Processing Record 3 of Set 11 | bossangoa
# Processing Record 4 of Set 11 | wagar
# Processing Record 5 of Set 11 | conceicao do araguaia
# Processing Record 6 of Set 11 | wanparti
# Processing Record 7 of Set 11 | san ignacio de velasco
# Processing Record 8 of Set 11 | laguna
# Processing Record 9 of Set 11 | zelow
# Processing Record 10 of Set 11 | kazanka
# Processing Record 11 of Set 11 | qoryooley
# Processing Record 12 of Set 11 | santander
# Processing Record 13 of Set 11 | talcahuano
# Processing Record 14 of Set 11 | itoigawa
# Processing Record 15 of Set 11 | puri
# Processing Record 16 of Set 11 | amga
# Processing Record 17 of Set 11 | cruzeiro do sul
# Processing Record 18 of Set 11 | cabo san lucas
# Processing Record 19 of Set 11 | medicine hat
# Processing Record 20 of Set 11 | katsuren-haebaru
# Processing Record 21 of Set 11 | demba
# Processing Record 22 of Set 11 | grootfontein
# Processing Record 23 of Set 11 | west bay
# Processing Record 24 of Set 11 | san matias
# Processing Record 25 of Set 11 | trashi yangtse
# Processing Record 26 of Set 11 | ayame
# Processing Record 27 of Set 11 | oranjemund
# Processing Record 28 of Set 11 | brigantine
# Processing Record 29 of Set 11 | ribadesella
# Processing Record 30 of Set 11 | kargasok
# Processing Record 31 of Set 11 | lucea
# Processing Record 32 of Set 11 | nguti
# Processing Record 33 of Set 11 | altus
# Processing Record 34 of Set 11 | oamaru
# Processing Record 35 of Set 11 | sittwe
# Processing Record 36 of Set 11 | columbia falls
# Processing Record 37 of Set 11 | nanma
# Processing Record 38 of Set 11 | beledweyne
# Processing Record 39 of Set 11 | labytnangi
# Processing Record 40 of Set 11 | kenai
# Processing Record 41 of Set 11 | south hedland
# Processing Record 42 of Set 11 | ibshaway
# Processing Record 43 of Set 11 | kurchatov
# Processing Record 44 of Set 11 | ar rass
# Processing Record 45 of Set 11 | santa quiteria
# Processing Record 46 of Set 11 | imperatriz
# Processing Record 47 of Set 11 | greenville
# Processing Record 48 of Set 11 | vanino
# Processing Record 49 of Set 11 | fasa
# Processing Record 0 of Set 12 | kittila
# Processing Record 1 of Set 12 | midvagur
# Processing Record 2 of Set 12 | camana
# Processing Record 3 of Set 12 | harlan
# Processing Record 4 of Set 12 | plastun
# Processing Record 5 of Set 12 | mount gambier
# Processing Record 6 of Set 12 | tongouson
# Processing Record 7 of Set 12 | odienne
# Processing Record 8 of Set 12 | akureyri
# Processing Record 9 of Set 12 | zhanibek
# Processing Record 10 of Set 12 | gurupi
# Processing Record 11 of Set 12 | betio village
# Processing Record 12 of Set 12 | bijar
# Processing Record 13 of Set 12 | ca mau
# Processing Record 14 of Set 12 | christchurch
# Processing Record 15 of Set 12 | talara
# Processing Record 16 of Set 12 | mazagao
# Processing Record 17 of Set 12 | la sarre
# Processing Record 18 of Set 12 | outjo
# Processing Record 19 of Set 12 | lokomotivnyy
# Processing Record 20 of Set 12 | sarandi del yi
# Processing Record 21 of Set 12 | merizo village
# Processing Record 22 of Set 12 | bathsheba
# Processing Record 23 of Set 12 | coahuayana de hidalgo
# Processing Record 24 of Set 12 | sao joao da barra
# Processing Record 25 of Set 12 | puerto leguizamo
# Processing Record 26 of Set 12 | bodo
# Processing Record 27 of Set 12 | corinto
# Processing Record 28 of Set 12 | aswan
# Processing Record 29 of Set 12 | myeik
# Processing Record 30 of Set 12 | touros
# Processing Record 31 of Set 12 | cestos city
# Processing Record 32 of Set 12 | hasaki
# Processing Record 33 of Set 12 | gizo
# Processing Record 34 of Set 12 | golyshmanovo
# Processing Record 35 of Set 12 | kharabali
# Processing Record 36 of Set 12 | fortuna
# Processing Record 37 of Set 12 | east london
# Processing Record 38 of Set 12 | yinchuan
# Processing Record 39 of Set 12 | greymouth
# Processing Record 40 of Set 12 | freetown
# Processing Record 41 of Set 12 | lauro de freitas
# Processing Record 42 of Set 12 | chittagong
# Processing Record 43 of Set 12 | chibougamau
# Processing Record 44 of Set 12 | halifax
# Processing Record 45 of Set 12 | praia
# Processing Record 46 of Set 12 | susaki
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          571
# Lat           571
# Lng           571
# Max Temp      571
# Humidity      571
# Cloudiness    571
# Wind Speed    571
# Country       571
# Date          571
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       adamstown -25.0660 -130.1015     19.33        56          84
# 1          avarua -21.2078 -159.7750     24.03        69          40
# 2  campina grande  -7.2306  -35.8811     19.90        88           0
# 3       bandipura  34.4167   74.6500     22.54        78          58
# 4        thompson  55.7435  -97.8558     15.09        77          20
#
#    Wind Speed Country        Date
# 0        9.81      PN  1691635216
# 1        7.20      CK  1691635312
# 2        3.60      BR  1691635312
# 3        0.84      IN  1691635312
# 4        0.00      CA  1691635312

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             adamstown -25.0660 -130.1015     19.33        56          84
# 1                avarua -21.2078 -159.7750     24.03        69          40
# 2        campina grande  -7.2306  -35.8811     19.90        88           0
# 3             bandipura  34.4167   74.6500     22.54        78          58
# 4              thompson  55.7435  -97.8558     15.09        77          20
#
#          Wind Speed Country        Date
# City_ID
# 0              9.81      PN  1691635216
# 1              7.20      CK  1691635312
# 2              3.60      BR  1691635312
# 3              0.84      IN  1691635312
# 4              0.00      CA  1691635312

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'],city_data_df['Max Temp'])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temp (C)")
plt.grid(True)
plt.title("City Latitude vs. Temperature")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'],city_data_df['Humidity'])
# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)
plt.title("City Latitude vs. Humidity")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'],city_data_df['Cloudiness'])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid(True)
plt.title("City Latitude vs. Cloudiness")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'],city_data_df['Wind Speed'])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid(True)
plt.title("City Latitude vs. Wind Speed")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Define a function to create Linear Regression plots
# ----> 2 (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
#       3 regress_values = x_values * slope + intercept
#       4 line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
#
# NameError: name 'x_values' is not defined

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df['Lat']) >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 3         bandipura  34.4167   74.6500     22.54        78          58
# 4          thompson  55.7435  -97.8558     15.09        77          20
# 5           bintulu   3.1667  113.0333     29.23        79          20
# 6        isafjordur  66.0755  -23.1240      6.85        82          44
# 7           awjilah  29.1081   21.2869     24.17        55           0
#
#          Wind Speed Country        Date
# City_ID
# 3              0.84      IN  1691635312
# 4              0.00      CA  1691635312
# 5              1.54      MY  1691635312
# 6              3.40      IS  1691635312
# 7              5.09      LY  1691635313

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df['Lat']) < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             adamstown -25.0660 -130.1015     19.33        56          84
# 1                avarua -21.2078 -159.7750     24.03        69          40
# 2        campina grande  -7.2306  -35.8811     19.90        88           0
# 10               padang  -0.9492  100.3543     29.03        81          62
# 11           lubumbashi -11.6609   27.4794     11.94        52           0
#
#          Wind Speed Country        Date
# City_ID
# 0              9.81      PN  1691635216
# 1              7.20      CK  1691635312
# 2              3.60      BR  1691635312
# 10             2.13      ID  1691635064
# 11             1.88      CD  1691635171

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
slope = linregress(x_values,y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,'r-')
plt.annotate(line_eq,(0,8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f'The r-value is: {rvalue}')
# Out:
# The r-value is: -0.6470349861877185

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
slope = linregress(x_values,y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,'r-')
plt.annotate(line_eq,(-25,0),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f'The r-value is: {rvalue}')
# Out:
# The r-value is: 0.7797707655937458

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
slope = linregress(x_values,y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,'r-')
plt.annotate(line_eq,(0,8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f'The r-value is: {rvalue}')
# Out:
# The r-value is: -0.09796790618512081

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
slope = linregress(x_values,y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,'r-')
plt.annotate(line_eq,(-25,40),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f'The r-value is: {rvalue}')
# Out:
# The r-value is: -0.034977913713973255

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
slope = linregress(x_values,y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,'r-')
plt.annotate(line_eq,(0,8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f'The r-value is: {rvalue}')
# Out:
# The r-value is: -0.08754768300469398

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']
slope = linregress(x_values,y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,'r-')
plt.annotate(line_eq,(-25,40),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f'The r-value is: {rvalue}')
# Out:
# The r-value is: -0.19649790712501183

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
slope = linregress(x_values,y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,'r-')
plt.annotate(line_eq,(0,8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f'The r-value is: {rvalue}')
# Out:
# The r-value is: -0.04852424559251013

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']
slope = linregress(x_values,y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,'r-')
plt.annotate(line_eq,(-25,40),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f'The r-value is: {rvalue}')
# Out:
# The r-value is: -0.06631824827176318

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
